# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import dataframe_image as dfi
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
f,a = plt.subplots(1,1,figsize=(1e-2, 1e-2))
mpl.rcParams['figure.dpi'] = 180
sns.set_style('darkgrid')
import os,sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import warnings
warnings.filterwarnings("ignore")

from tqdm.auto import tqdm
from datetime import datetime as dt
from src.utils import mkdirs, convert_path, pkl_dump, pkl_load, display_side, add_median_labels
from src.data_processing import get_dataset, BL62_VALUES, BL62FREQ_VALUES, HLAS, AA_KEYS, get_aa_properties
from src.metrics import get_predictions, get_roc, get_metrics, plot_roc_auc_fold, get_mean_roc_curve
from src.metrics import get_nested_feature_importance, plot_feature_importance
from src.utils import pkl_load, pkl_dump, get_palette
from src.bootstrap import bootstrap_eval, get_pval, plot_pval
from src.bootstrap import get_pval, plot_pval
import torch
from torch import nn
from torch import functional as F
PAL = sns.color_palette('hsv', n_colors=13)
HSV = [PAL[-4], PAL[-1], PAL[0], PAL [4]]
tmppal = sns.color_palette('hsv', n_colors=15)
NEWPAL = HSV + [tmppal[-3], tmppal[7]]
mpl.rcParams['figure.dpi'] = 180

# %%
cedar_aligned = pd.read_csv('../data/aligned_icore/230418_cedar_aligned.csv')
prime_aligned = pd.read_csv('../data/aligned_icore/230418_prime_aligned.csv')
viral = pd.read_csv('../data/other/viral.csv').rename(columns={'sequence':'Peptide'})

# %% [markdown]
# # self explo

# %%
from src.models import *

# %%
def sliding_window(x, window_size):
    # Compute the number of windows per sequence
    num_windows = x.size(1) - window_size + 1

    # Create a tensor of shape (N, num_windows, window_size, D) containing the sliding windows
    windows = torch.nn.functional.unfold(x.transpose(1, 2), (window_size, 1)).transpose(1, 2).view(x.size(0), num_windows, window_size, x.size(2))

    # Mask out the padded positions
    mask = (x != 0).unsqueeze(-1).expand_as(windows)
    windows = torch.masked_select(windows, mask).view(x.size(0), num_windows, -1)

    return windows

# %%
from src.data_processing import encode_batch
sample = cedar_aligned.sample(100, random_state=100)
sample.head()
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        HLA  agg_label  fold  \
# 996            996           996         996  HLA-A0201          0     1
# 249            249           249         249  HLA-A2402          0     5
# 774            774           774         774  HLA-B3901          0     7
# 1617          1617          1617        1617  HLA-C0702          1     8
# 3004          3004          3004        3004  HLA-B0801          0     1
#
#          Peptide   wild_type  icore_mut   core_mut  ...  \
# 996   IMQPSVVIPA  IVQPSVVIPA  MQPSVVIPA  MQPSVVIPA  ...
# 249    AYLEAIHTF   AYLEAIHNF  AYLEAIHTF  AYLEAIHTF  ...
# 774    GRMRSLEAL   GRMRCLEAL  GRMRSLEAL  GRMRSLEAL  ...
# 1617  LYIWFKTACL  LYLWFKTACL  YIWFKTACL  YIWFKTACL  ...
# 3004   YTTVRALTL   YTTVRALTR  YTTVRALTL  YTTVRALTL  ...
#
#       icore_improves_binder_0_75  mixed_input_binder_0_75  \
# 996                        False               IMQPSVVIPA
# 249                        False                AYLEAIHTF
# 774                        False                GRMRSLEAL
# 1617                       False               LYIWFKTACL
# 3004                       False                YTTVRALTL
#
#       mixed_rank_binder_0_75  icore_improves_1  mixed_input_1  mixed_rank_1  \
# 996                   2.8394             False     IMQPSVVIPA        2.8394
# 249                   0.0006             False      AYLEAIHTF        0.0006
# 774                   0.2547             False      GRMRSLEAL        0.2547
# 1617                  4.9286             False     LYIWFKTACL        4.9286
# 3004                  0.1560             False      YTTVRALTL        0.1560
#
#      icore_improves_binder_1  mixed_input_binder_1  mixed_rank_binder_1  \
# 996                    False            IMQPSVVIPA               2.8394
# 249                    False             AYLEAIHTF               0.0006
# 774                    False             GRMRSLEAL               0.2547
# 1617                   False            LYIWFKTACL               4.9286
# 3004                   False             YTTVRALTL               0.1560
#
#       expanded_input
# 996        MQPSVVIPA
# 249        AYLEAIHTF
# 774        GRMRSLEAL
# 1617       YIWFKTACL
# 3004       YTTVRALTL
#
# [5 rows x 70 columns]

# %%
x = encode_batch(sample['Peptide'].values, 12, 'onehot')
x.shape
# Out:
# torch.Size([100, 12, 20])

# %%
# Say K = 5
max_len = 12
N = 3
K = 5
x_base = torch.rand([N, max_len, 20])
x = x.view(N,-1)
y = torch.randint(1, size=(N, 1)).float()
y[N-1]=1
y_exp = y.expand((N, max_len-K+1)).view(-1, max_len-K+1, 1)


criterion = nn.BCEWithLogitsLoss(reduction='none')
# Here need to fix expander to return the x_expand_flat 
xp = InputExpander(window_size=K, max_len=max_len, indel=False)
z=xp(x_base)

n_hidden = 10
model = nn.Sequential(nn.Linear(K*20, n_hidden), nn.ReLU(), nn.Linear(n_hidden, 1))

# expanding input stuff
x_sliding = x_base.unfold(1, K, 1)
# Reshape the tensor to the desired output shape
x_expand = x_sliding.transpose(2, 3).reshape(len(x_base), max_len-K+1, K, 20)
x_expand_flat = x_expand.flatten(2,3)

y_pred = model(x_expand_flat)
# x_expand should be correct and z is transposed i.e. wrong
x_expand.shape, z.shape, x_base.shape, (x_base[0][3:3+K,:] == x_expand[0,3,:]).all(), x_expand_flat.shape
# Out:
# (torch.Size([3, 8, 5, 20]),
#  torch.Size([3, 5, 8, 20]),
#  torch.Size([3, 12, 20]),
#  tensor(True),
#  torch.Size([3, 8, 100]))

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.nn.functional import binary_cross_entropy_with_logits as bce_with_logits

class SlidingWindowDataset(Dataset):
    def __init__(self, x, y, window_size):
        self.x = x
        self.y = y
        self.window_size = window_size

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x_window = self.x[idx][:, None, :]
        x_window = nn.functional.unfold(x_window, (1, self.window_size))[0]
        y = self.y[idx]
        return x_window, y

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.linear1 = nn.Linear(20, 10)
        self.relu1 = nn.ReLU()
        self.linear2 = nn.Linear(10, 1)

    def forward(self, x):
        x = self.linear1(x)
        x = self.relu1(x)
        x = self.linear2(x)
        return x

def train(model, optimizer, criterion, dataloader):
    model.train()
    total_loss = 0.0
    for x_batch, y_batch in dataloader:
        optimizer.zero_grad()
        y_pred = model(x_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(x_batch)
    return total_loss / len(dataloader.dataset)

def evaluate(model, criterion, dataloader):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for x_batch, y_batch in dataloader:
            y_pred = model(x_batch)
            loss = criterion(y_pred, y_batch)
            total_loss += loss.item() * len(x_batch)
    return total_loss / len(dataloader.dataset)

# Define the input tensor x and target tensor y
x = torch.randn(3000, 10, 20)
y = torch.randint(0, 2, (3000, 1)).float()

# Define the window size and batch size
window_size = 5
batch_size = 128

# Define the dataset and dataloader
dataset = SlidingWindowDataset(x, y, window_size)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Define the model, loss function, and optimizer
model = Net()
criterion = nn.BCEWithLogitsLoss()
optimizer = Adam(model.parameters())

# Train the model
for epoch in range(10):
    train_loss = train(model, optimizer, criterion, dataloader)
    valid_loss = evaluate(model, criterion, dataloader)
    print(f"Epoch {epoch + 1:03d}, Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}")

# Compute the best scores
model.eval()
best_scores = []
with torch.no_grad():
    for x_batch, y_batch in dataloader:
        scores = model(x_batch).squeeze()
        losses = bce_with_logits(scores, y_batch)
        best_indices = losses.argmin(dim=1)
        best_scores_batch = scores.gather(1, best_indices.view(-1, 1)).view(-1, 1)
        best_scores.append

# %% [markdown]
# # tests

# %%
from src.models import NNAlign, NNAlignWrapper
from src.datasets import NNAlignDataset, get_NNAlign_dataloader
from src.train_eval import train_model_step, eval_model_step
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch import optim

window_size = 6
max_len = 12
n_hidden = 50
p_drop = 0.25
encoding = 'BL62LO'
indel=False
n_epochs = 500
activation = nn.SELU()
model = NNAlignWrapper(n_hidden=n_hidden, window_size=window_size, activation = activation, dropout=p_drop)

train, test = train_test_split(cedar_aligned, test_size=1/4)
valid, test = train_test_split(test, test_size=1/2)

train_dataset = NNAlignDataset(train, max_len, window_size, encoding=encoding)
train_loader = DataLoader(train_dataset, batch_size = 128, sampler=torch.utils.data.RandomSampler(valid_dataset))

x,y = train_dataset[:10]
print('checking padded inputs\n', x[3][-1].view(window_size, 20))


valid_dataset = NNAlignDataset(valid, max_len, window_size, encoding=encoding)
valid_loader = DataLoader(valid_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(valid_dataset))

test_dataset = NNAlignDataset(test, max_len, window_size, encoding=encoding)
test_loader = DataLoader(test_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(test_dataset))

prime_aligned = pd.read_csv('../data/aligned_icore/230418_prime_aligned.csv')
prime_dataset = NNAlignDataset(prime_aligned, max_len, window_size, encoding=encoding)
prime_loader = DataLoader(prime_dataset, batch_size=64, sampler=torch.utils.data.RandomSampler(prime_dataset))


optimizer = optim.Adam(model.parameters(), lr = 1e-4, weight_decay = 1e-2)
criterion = nn.BCEWithLogitsLoss(reduction='mean')

train_losses=[]
valid_losses=[]
test_losses=[]
prime_losses = []
train_aucs=[]
valid_aucs=[]
test_aucs=[]
prime_aucs = []

print('Before training')
loss, metrics = eval_model_step(model, criterion, train_loader)
train_losses.append(loss)
train_aucs.append(metrics['auc'])
print('train', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, valid_loader)
valid_losses.append(loss)
valid_aucs.append(metrics['auc'])
print('valid', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, test_loader)
test_losses.append(loss)
test_aucs.append(metrics['auc'])
print('eval', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, prime_loader)
prime_losses.append(loss)
prime_aucs.append(metrics['auc'])        
print('prime', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3),'\n\n')
for e in range(1,n_epochs+1):
    loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print(f'EPOCH = {e}\n\n')
        print('train', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, valid_loader)
    valid_losses.append(loss)
    valid_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('valid', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('eval', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, prime_loader)
    prime_losses.append(loss)
    prime_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('prime', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3),'\n\n')
# Out:
# checking padded inputs
#  tensor([[  1.,  -1.,   1.,   0.,  -1.,   0.,   0.,   0.,  -1.,  -2.,  -2.,   0.,
#           -1.,  -2.,  -1.,   4.,   1.,  -3.,  -2.,  -2.],
#         [  1.,  -1.,   1.,   0.,  -1.,   0.,   0.,   0.,  -1.,  -2.,  -2.,   0.,
#           -1.,  -2.,  -1.,   4.,   1.,  -3.,  -2.,  -2.],
#         [ -1.,  -2.,  -3.,  -4.,  -1.,  -2.,  -3.,  -4.,  -3.,   2.,   4.,  -2.,
#            2.,   0.,  -3.,  -2.,  -1.,  -2.,  -1.,   1.],
#         [-12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12.,
#          -12., -12., -12., -12., -12., -12., -12., -12.],
#         [-12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12.,
#          -12., -12., -12., -12., -12., -12., -12., -12.],
#         [-12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12., -12.,
#          -12., -12., -12., -12., -12., -12., -12., -12.]])
# Before training
# train 1.242e-01 auc 0.444 auc_01 0.487 acc 0.388 prec 0.172
# valid 7.267e-01 auc 0.536 auc_01 0.487 acc 0.48 prec 0.22
# eval 7.419e-01 auc 0.436 auc_01 0.478 acc 0.405 prec 0.192
# prime 7.411e-01 auc 0.457 auc_01 0.489 acc 0.416 prec 0.038
#
#
# EPOCH = 1
#
#
# train 1.269e-01 auc 0.409 auc_01 0.488 acc 0.441 prec 0.169
# valid 6.893e-01 auc 0.531 auc_01 0.488 acc 0.565 prec 0.238
# eval 7.028e-01 auc 0.431 auc_01 0.478 acc 0.5 prec 0.171
# prime 6.816e-01 auc 0.456 auc_01 0.489 acc 0.564 prec 0.039
#
#
# EPOCH = 50
#
#
# train 8.271e-02 auc 0.612 auc_01 0.555 acc 0.802 prec 0.75
# valid 4.923e-01 auc 0.612 auc_01 0.527 acc 0.797 prec 0.0
# eval 5.049e-01 auc 0.574 auc_01 0.516 acc 0.795 prec 0.0
# prime 2.934e-01 auc 0.548 auc_01 0.512 acc 0.958 prec 0.0
#
#
# EPOCH = 100
#
#
# train 7.520e-02 auc 0.744 auc_01 0.568 acc 0.797 prec 0.6
# valid 4.914e-01 auc 0.622 auc_01 0.531 acc 0.794 prec 0.0
# eval 5.031e-01 auc 0.598 auc_01 0.518 acc 0.795 prec 0.5
# prime 2.899e-01 auc 0.574 auc_01 0.517 acc 0.95 prec 0.0
#
#
# EPOCH = 150
#
#
# train 7.152e-02 auc 0.781 auc_01 0.602 acc 0.792 prec 0.5
# valid 4.938e-01 auc 0.625 auc_01 0.534 acc 0.792 prec 0.0
# eval 5.007e-01 auc 0.62 auc_01 0.522 acc 0.79 prec 0.333
# prime 2.926e-01 auc 0.587 auc_01 0.518 acc 0.94 prec 0.075
#
#
# EPOCH = 200
#
#
# train 6.552e-02 auc 0.847 auc_01 0.654 acc 0.815 prec 0.765
# valid 4.973e-01 auc 0.625 auc_01 0.537 acc 0.776 prec 0.0
# eval 5.029e-01 auc 0.628 auc_01 0.525 acc 0.782 prec 0.222
# prime 2.913e-01 auc 0.591 auc_01 0.519 acc 0.929 prec 0.057
#
#
# EPOCH = 250
#
#
# train 6.611e-02 auc 0.83 auc_01 0.654 acc 0.839 prec 0.737
# valid 5.001e-01 auc 0.63 auc_01 0.539 acc 0.778 prec 0.267
# eval 5.056e-01 auc 0.637 auc_01 0.521 acc 0.776 prec 0.316
# prime 2.973e-01 auc 0.594 auc_01 0.521 acc 0.923 prec 0.083
#
#
# EPOCH = 300
#
#
# train 6.063e-02 auc 0.883 auc_01 0.684 acc 0.834 prec 0.767
# valid 5.037e-01 auc 0.632 auc_01 0.539 acc 0.776 prec 0.278
# eval 5.089e-01 auc 0.642 auc_01 0.522 acc 0.771 prec 0.304
# prime 2.969e-01 auc 0.596 auc_01 0.524 acc 0.914 prec 0.084
#
#
# EPOCH = 350
#
#
# train 6.111e-02 auc 0.876 auc_01 0.67 acc 0.823 prec 0.7
# valid 5.091e-01 auc 0.629 auc_01 0.54 acc 0.778 prec 0.333
# eval 5.131e-01 auc 0.646 auc_01 0.522 acc 0.774 prec 0.333
# prime 2.966e-01 auc 0.597 auc_01 0.526 acc 0.909 prec 0.077
#
#
# EPOCH = 400
#
#
# train 5.785e-02 auc 0.896 auc_01 0.709 acc 0.842 prec 0.757
# valid 5.129e-01 auc 0.631 auc_01 0.542 acc 0.786 prec 0.417
# eval 5.167e-01 auc 0.649 auc_01 0.521 acc 0.776 prec 0.36
# prime 3.018e-01 auc 0.597 auc_01 0.526 acc 0.903 prec 0.082
#
#
# EPOCH = 450
#
#
# train 5.590e-02 auc 0.892 auc_01 0.742 acc 0.871 prec 0.917
# valid 5.175e-01 auc 0.632 auc_01 0.543 acc 0.789 prec 0.44
# eval 5.205e-01 auc 0.653 auc_01 0.524 acc 0.776 prec 0.37
# prime 2.991e-01 auc 0.599 auc_01 0.528 acc 0.9 prec 0.083
#
#
# EPOCH = 500
#
#
# train 5.428e-02 auc 0.902 auc_01 0.742 acc 0.871 prec 0.857
# valid 5.230e-01 auc 0.63 auc_01 0.542 acc 0.773 prec 0.364
# eval 5.248e-01 auc 0.654 auc_01 0.524 acc 0.771 prec 0.345
# prime 3.043e-01 auc 0.599 auc_01 0.531 acc 0.896 prec 0.082

# %%
f,a = plt.subplots(2,1, figsize=(10,9))
a = a.ravel()
a[0].plot(train_losses, label='train_losses')
a[0].plot(valid_losses, label='valid_losses')
a[0].plot(test_losses, label='test_losses')
a[0].plot(prime_losses, label='prime_losses')
a[0].legend()
a[0].set_title('loss')
a[1].plot(train_aucs, label='train_aucs')
a[1].plot(valid_aucs, label='valid_aucs')
a[1].plot(test_aucs, label='test_aucs')
a[1].plot(prime_aucs, label='prime_aucs')
a[1].legend()
a[1].set_title('AUC')
a[1].set_xlabel('epochs')
f.suptitle('Dropout only')
# Out:
# Text(0.5, 0.98, 'Dropout only')

# %%
from src.models import NNAlign, NNAlignWrapper
from src.datasets import NNAlignDataset, get_NNAlign_dataloader
from src.train_eval import train_model_step, eval_model_step
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch import optim

window_size = 6
max_len = 12
n_hidden = 50
p_drop = 0.25
encoding = 'BL62LO'
indel=False
n_epochs = 500

train, test = train_test_split(cedar_aligned, test_size=1/4)
valid, test = train_test_split(test, test_size=1/2)

train_dataset = NNAlignDataset(train, max_len, window_size, encoding=encoding)
train_loader = DataLoader(train_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(valid_dataset))

x,y = train_dataset[:10]
print('checking padded inputs\n', x[3][-1].view(window_size, 20))


valid_dataset = NNAlignDataset(valid, max_len, window_size, encoding=encoding)
valid_loader = DataLoader(valid_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(valid_dataset))

test_dataset = NNAlignDataset(test, max_len, window_size, encoding=encoding)
test_loader = DataLoader(test_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(test_dataset))

prime_aligned = pd.read_csv('../data/aligned_icore/230418_prime_aligned.csv')
prime_dataset = NNAlignDataset(prime_aligned, max_len, window_size, encoding=encoding)
prime_loader = DataLoader(prime_dataset, batch_size=64, sampler=torch.utils.data.RandomSampler(prime_dataset))


model = NNAlignWrapper(n_hidden=n_hidden, window_size=window_size, activation = nn.SELU(), dropout=p_drop)
optimizer = optim.Adam(model.parameters(), lr = 1e-4, weight_decay = 1e-2)
criterion = nn.BCEWithLogitsLoss(reduction='mean')

train_losses=[]
valid_losses=[]
test_losses=[]
prime_losses = []
train_aucs=[]
valid_aucs=[]
test_aucs=[]
prime_aucs = []

print('Before training')
loss, metrics = eval_model_step(model, criterion, train_loader)
train_losses.append(loss)
train_aucs.append(metrics['auc'])
print('train', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, valid_loader)
valid_losses.append(loss)
valid_aucs.append(metrics['auc'])
print('valid', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, test_loader)
test_losses.append(loss)
test_aucs.append(metrics['auc'])
print('eval', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
loss, metrics = eval_model_step(model, criterion, prime_loader)
prime_losses.append(loss)
prime_aucs.append(metrics['auc'])        
print('prime', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3),'\n\n')
for e in range(1,n_epochs+1):
    loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print(f'EPOCH = {e}\n\n')
        print('train', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, valid_loader)
    valid_losses.append(loss)
    valid_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('valid', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('eval', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3))
    loss, metrics = eval_model_step(model, criterion, prime_loader)
    prime_losses.append(loss)
    prime_aucs.append(metrics['auc'])
    if e%int(n_epochs/10)==0 or e ==1:
        print('prime', f'{loss:.3e}', 'auc', round(metrics['auc'],3), 'auc_01', round(metrics['auc_01'],3), 'acc', round(metrics['accuracy'],3), 'prec', round(metrics['precision'],3),'\n\n')
        
f,a = plt.subplots(2,1, figsize=(10,9))
a = a.ravel()
a[0].plot(train_losses, label='train_losses')
a[0].plot(valid_losses, label='valid_losses')
a[0].plot(test_losses, label='test_losses')
a[0].plot(prime_losses, label='prime_losses')
a[0].legend()
a[0].set_title('loss')
a[1].plot(train_aucs, label='train_aucs')
a[1].plot(valid_aucs, label='valid_aucs')
a[1].plot(test_aucs, label='test_aucs')
a[1].plot(prime_aucs, label='prime_aucs')
a[1].legend()
a[1].set_title('AUC')
a[1].set_xlabel('epochs')
f.suptitle('Dropout batchnorm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 20>()
#      17 valid, test = train_test_split(test, test_size=1/2)
#      19 train_dataset = NNAlignDataset(train, max_len, window_size, encoding=encoding)
# ---> 20 train_loader = DataLoader(train_dataset, batch_size = 64, sampler=torch.utils.data.RandomSampler(valid_dataset))
#      22 x,y = train_dataset[:10]
#      23 print('checking padded inputs\n', x[3][-1].view(window_size, 20))
#
# NameError: name 'valid_dataset' is not defined

# %% [markdown]
# # Some quick HP tuning

# %%
(500/25)
# Out:
# 20.0

# %%
def parallel_wrapper(df_train, df_valid, df_test, df_prime, standardize, encoding, n_hidden, p_drop, batchnorm, activation, batch_size=64, n_epochs = 500, lr = 1e-4, wd = 1e-2):

    
    model = NNAlign(n_hidden=n_hidden, window_size=window_size, activation = activation, dropout=p_drop, standardize =standardize, singlepass=True, indel=False)  
    
    train_loader, train_dataset = get_NNAlign_dataloader(df_train, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=True)
    valid_loader = get_NNAlign_dataloader(df_valid, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)
    test_loader = get_NNAlign_dataloader(df_test, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)
    prime_loader = get_NNAlign_dataloader(df_prime, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)
                         
    if hasattr(model, 'standardizer'):
        model.fit_standardizer(train_dataset[:][0])
        
    criterion = nn.BCEWithLogitsLoss(reduction='mean')
    optimizer = optim.Adam(model.parameters(), lr = lr, weight_decay = wd)
    
    train_losses = []
    valid_losses = []
    prime_losses = []
    test_losses = []

    train_aucs = []
    valid_aucs = []
    prime_aucs = []
    test_aucs = []


    loss, metrics = eval_model_step(model, criterion, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, valid_loader)
    valid_losses.append(loss)
    valid_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, prime_loader)
    prime_losses.append(loss)
    prime_aucs.append(metrics['auc'])        
    
    for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
        loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
        train_losses.append(loss)
        train_aucs.append(metrics['auc'])
        loss, metrics = eval_model_step(model, criterion, valid_loader)
        valid_losses.append(loss)
        valid_aucs.append(metrics['auc'])
        loss, metrics = eval_model_step(model, criterion, test_loader)
        test_losses.append(loss)
        test_aucs.append(metrics['auc'])
        loss, metrics = eval_model_step(model, criterion, prime_loader)
        prime_losses.append(loss)
        prime_aucs.append(metrics['auc'])
            
    f,a = plt.subplots(2,1, figsize=(12,10))
    a = a.ravel()
    a[0].plot(train_losses, label='train_losses')
    a[0].plot(valid_losses, label='valid_losses')
    a[0].plot(test_losses, label='test_losses')
    a[0].plot(prime_losses, label='prime_losses')
    a[0].legend()
    a[0].set_title('loss')
    a[1].plot(train_aucs, label='train_aucs')
    a[1].plot(valid_aucs, label='valid_aucs')
    a[1].plot(test_aucs, label='test_aucs')
    a[1].plot(prime_aucs, label='prime_aucs')
    a[1].legend()
    a[1].set_title('AUC')
    a[1].set_xlabel('epochs')
    f.suptitle(f'Std:{standardize}, nh:{n_hidden}, drop:{p_drop}, BN:{batchnorm},\nBS:{batch_size}, act:{activation.__class__.__name__}, enc:{encoding}, lr:{lr:.2e}, wd:{wd:.2e}')
    filename=f'std_{standardize}_nh_{n_hidden}_drop_{p_drop}_bn_{batchnorm}_bs_{batch_size}_act_{activation.__class__.__name__}_enc_{encoding}_lr1em4_wd_1em2'
    f.tight_layout()
    f.savefig(f'../output/230516_NNAlign_hp_tune_checks/{filename}.png', bbox_inches='tight', dpi=200)
    dd={'best_train_loss': np.min(train_losses),
     'best_train_loss_idx': np.argmin(train_losses),
     'best_valid_loss': np.min(valid_losses),
     'best_valid_loss_idx': np.argmin(valid_losses),
     'best_prime_loss': np.min(prime_losses),
     'best_prime_loss_idx': np.argmin(prime_losses),
     'best_test_loss': np.min(test_losses),
     'best_test_loss_idx': np.argmin(test_losses),
     
     'best_train_auc': np.max(train_aucs),
     'best_train_auc_idx': np.argmax(train_aucs),
     'best_valid_auc': np.max(valid_aucs),
     'best_valid_auc_idx': np.argmax(valid_aucs),
     'best_prime_auc': np.max(prime_aucs),
     'best_prime_auc_idx': np.argmax(prime_aucs),
     'best_test_auc': np.max(test_aucs),
     'best_test_auc_idx': np.argmax(test_aucs),
     'std': standardize,
     'n_hidden':n_hidden,
     'drop':p_drop,
     'batchnorm':batchnorm,
     'batchsize':batch_size,
     'act':activation.__class__.__name__,
     'encoding':encoding}
    return pd.DataFrame(dd, index=[0])

# %%
from src.models import NNAlignDoublePass, NNAlignSinglePass, NNAlign
from src.datasets import NNAlignDataset, get_NNAlign_dataloader
from src.train_eval import train_model_step, eval_model_step
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch import optim
import itertools
from functools import partial
from joblib import Parallel, delayed

lr = 1e-4
wd = 1e-2
window_size = 6
max_len = 12
n_hidden = 50
n_epochs = 500
seed = 13 
torch.manual_seed(seed)
df_train, df_test = train_test_split(cedar_aligned, test_size=1/4, random_state=seed)
df_valid, df_test = train_test_split(df_test, test_size=1/2, random_state=seed)
df_prime = prime_aligned.query('Peptide not in @df_train.Peptide.values')
criterion = nn.BCEWithLogitsLoss(reduction='mean')
# this cell won't run anymore as of 230524.
# Here, the old version that used NNalign (=double pass, no std) vs NNAlignWrapper (=double pass, with std)
cdts = list(itertools.product([True, False], ['BL62LO', 'BL50LO', 'BL62FREQ'], [10, 25, 50], [0, 0.3], [False, True], [nn.SELU(), nn.ReLU()], [64, 128]))


wrapper = partial(parallel_wrapper, df_train=df_train, df_valid=df_valid, df_test=df_test, df_prime=df_prime, 
                  n_epochs = n_epochs, lr = lr, wd=wd)

out = Parallel(n_jobs=5)(delayed(wrapper)(standardize=std, encoding=enc, n_hidden=nh, p_drop=pd, batchnorm=bn, activation=act, batch_size=bs) for std, enc, nh, pd, bn, act, bs in tqdm(cdts, desc='conditions'))
out = pd.concat(out)
# Out:
# conditions:   0%|          | 0/288 [00:00<?, ?it/s]

# %%
out.to_csv('../output/230516_NNAlign_hp_tune_checks/output.csv')

# %%
out.groupby([ 'std',
'n_hidden',
'drop',
'batchnorm',
'batchsize',
'act',
'encoding']).agg(best_valid_auc = ('best_valid_auc', 'max'),
                 best_test_auc = ('best_test_auc', 'max'),
                best_prime_auc= ('best_prime_auc','max')).sort_values('best_prime_auc', ascending=False).head(10)
# Out:
#                                                        best_valid_auc  \
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ          0.7248
# False 25       0.0  True      64        SELU BL50LO            0.7582
# True  10       0.3  True      64        ReLU BL62FREQ          0.7331
# False 25       0.3  False     128       ReLU BL50LO            0.7367
# True  50       0.0  False     64        ReLU BL50LO            0.7737
# False 10       0.0  False     128       SELU BL50LO            0.7278
#       25       0.3  True      128       SELU BL62LO            0.7293
# True  25       0.0  False     64        SELU BL62LO            0.7504
#       10       0.3  False     64        SELU BL62LO            0.7306
#       25       0.0  False     128       ReLU BL62LO            0.7271
#
#                                                        best_test_auc  \
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ         0.6569
# False 25       0.0  True      64        SELU BL50LO           0.6849
# True  10       0.3  True      64        ReLU BL62FREQ         0.6429
# False 25       0.3  False     128       ReLU BL50LO           0.6488
# True  50       0.0  False     64        ReLU BL50LO           0.7030
# False 10       0.0  False     128       SELU BL50LO           0.6692
#       25       0.3  True      128       SELU BL62LO           0.6657
# True  25       0.0  False     64        SELU BL62LO           0.6797
#       10       0.3  False     64        SELU BL62LO           0.6634
#       25       0.0  False     128       ReLU BL62LO           0.6201
#
#                                                        best_prime_auc
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ          0.6975
# False 25       0.0  True      64        SELU BL50LO            0.6877
# True  10       0.3  True      64        ReLU BL62FREQ          0.6874
# False 25       0.3  False     128       ReLU BL50LO            0.6797
# True  50       0.0  False     64        ReLU BL50LO            0.6764
# False 10       0.0  False     128       SELU BL50LO            0.6744
#       25       0.3  True      128       SELU BL62LO            0.6727
# True  25       0.0  False     64        SELU BL62LO            0.6707
#       10       0.3  False     64        SELU BL62LO            0.6686
#       25       0.0  False     128       ReLU BL62LO            0.6677

# %% [markdown]
# # Running single fwd pass instead of double pass

# %%
from src.models import NNAlign, NNAlignWrapper
from src.datasets import NNAlignDataset, get_NNAlign_dataloader
from src.train_eval import train_model_step, eval_model_step
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from torch import optim
import itertools
from functools import partial
from joblib import Parallel, delayed

# %%
from src.models import NNAlignSinglePass
df_train, df_test = train_test_split(cedar_aligned, test_size=1/5, random_state=13)
train_loader, train_dataset = get_NNAlign_dataloader(train, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=True)
test_loader = get_NNAlign_dataloader(test, max_len, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)   

hp = dict(n_hidden=30, window_size=6, p_drop=0, batchnorm=True, activation=nn.ReLU(), batch_size=64, n_epochs=300, lr=1e-4, wd=1e-2)
model = NNAlignSinglePass(hp['n_hidden'], hp['window_size'], hp['activation'], hp['batchnorm'], hp['p_drop'])


criterion = nn.BCEWithLogitsLoss(reduction='mean')
optimizer = optim.Adam(model.parameters(), lr = lr, weight_decay = wd)

train_losses = []
test_losses = []

train_aucs = []
test_aucs = []


print('Before training')
loss, metrics = eval_model_step(model, criterion, train_loader)
train_losses.append(loss)
train_aucs.append(metrics['auc'])
loss, metrics = eval_model_step(model, criterion, test_loader)
test_losses.append(loss)
test_aucs.append(metrics['auc'])

for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
    loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
# Out:
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [59], in <cell line: 28>()
#      26 test_aucs.append(metrics['auc'])
#      28 for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
# ---> 29     loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
#      30     train_losses.append(loss)
#      31     train_aucs.append(metrics['auc'])
#
# File ~/Documents/code/PyNNalign/src/train_eval.py:104, in train_model_step(model, criterion, optimizer, train_loader)
#     102 optimizer.zero_grad()
#     103 loss.backward()
# --> 104 optimizer.step()
#     105 #
#     106 # # Here select the best scoring kmers as output, then computes metrics
#     107 # with torch.no_grad():
#    (...)
#     112 #     # Since all labels are the same for sub-kmers, just take an index and flatten it
#     113 #     y_true.append(y_train[:,0].flatten())
#     115 y_true.append(y_train)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:307, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     304 else:
#     305     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 307 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %% [markdown]
# # Running comparisons with the actual NNAlign model

# %%
from datetime import datetime as dt
# old defs before refactoring, likely won't run without changing the NNalign model constructor calls etc.
def run(df_train, df_test, model_constructor, encoding, n_hidden, window_size, p_drop, batchnorm, activation, 
        batch_size=64, n_epochs = 500, lr = 1e-4, wd = 1e-2, id_='', outdir='../output/', seed=13, singlepass=False,):
    start = dt.now()
    torch.manual_seed(seed)
    model = model_constructor(n_hidden=n_hidden, window_size=window_size, activation = activation, dropout=p_drop, singlepass=singlepass)
    train_loader, train_dataset = get_NNAlign_dataloader(df_train, 12, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=True)
    test_loader = get_NNAlign_dataloader(df_test, 12, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)
                         
    if hasattr(model, 'standardizer'):
        model.fit_standardizer(train_dataset[:][0])
        
    criterion = nn.BCEWithLogitsLoss(reduction='mean')
    optimizer = optim.Adam(model.parameters(), lr = lr, weight_decay = wd)
    
    train_losses = []
    test_losses = []

    train_aucs = []
    test_aucs = []


    print('Before training')
    loss, metrics = eval_model_step(model, criterion, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
    
    
    for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
        if e==1:print('Start training')
        loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
        train_losses.append(loss)
        train_aucs.append(metrics['auc'])
        loss, metrics = eval_model_step(model, criterion, test_loader)
        test_losses.append(loss)
        test_aucs.append(metrics['auc'])
    end = dt.now()
    elapsed = (end-start).seconds
    
    f,a = plt.subplots(2,1, figsize=(12,10))
    a = a.ravel()
    a[0].plot(train_losses, label='train_losses')
    a[0].plot(test_losses, label='test_losses')
    a[0].legend()
    a[0].set_title('loss')
    a[1].plot(train_aucs, label='train_aucs')
    a[1].plot(test_aucs, label='test_aucs')
    a[1].legend()
    a[1].set_title('AUC')
    a[1].set_xlabel('epochs')
    f.suptitle(f'IDENTIFIER: {id_}\nStd:{hasattr(model, "standardizer")}, nh:{n_hidden}, drop:{p_drop}, BN:{batchnorm},\nBS:{batch_size}, act:{activation.__class__.__name__}, enc:{encoding}, lr:{lr:.2e}, wd:{wd:.2e}')
    filename=f'ID_{id_}_SEED_{seed}_std_{hasattr(model, "standardizer")}_nh_{n_hidden}_drop_{p_drop}_bn_{batchnorm}_bs_{batch_size}_act_{activation.__class__.__name__}_enc_{encoding}_lr1em4_wd_1em2'
    f.tight_layout()
    f.savefig(f'../output/{outdir}{filename}.png', bbox_inches='tight', dpi=200)
    
    dd={'best_train_loss': np.min(train_losses),
     'best_train_loss_idx': np.argmin(train_losses),
     'best_test_loss': np.min(test_losses),
     'best_test_loss_idx': np.argmin(test_losses),
     'best_train_auc': np.max(train_aucs),
     'best_train_auc_idx': np.argmax(train_aucs),
     'best_test_auc': np.max(test_aucs),
     'best_test_auc_idx': np.argmax(test_aucs),
     'std': hasattr(model, 'standardizer'),
     'n_hidden':n_hidden,
     'drop':p_drop,
     'batchnorm':batchnorm,
     'batchsize':batch_size,
     'act':activation.__class__.__name__,
     'encoding':encoding,
       'identifier':id_,
       'seed':seed,
       'elapsed_seconds':elapsed}
    return pd.DataFrame(dd, index=[0])

# %% [markdown]
# ## First, compare double fwd pass to single pass

# %%
def singledouble_wrapper(dataset, hp, seed):
    torch.manual_seed(seed)
    df_train, df_test = train_test_split(dataset, test_size=1/10, random_state=seed)
    # double pass (normal)
    hyperparameters['singlepass']=False
    result_double = run(df_train, df_test.query('Peptide not in @df_train.Peptide.values'), NNAlignWrapper, 'BL50LO', outdir='../output/230522_singledouble_compare/',id_='normal_doublepass', seed=seed, **hp)
    # Single pass (new)
    hyperparameters['singlepass']=True
    result_single = run(df_train, df_test.query('Peptide not in @df_train.Peptide.values'), NNAlignWrapper, 'BL50LO', outdir='../output/230522_singledouble_compare/',id_='test_singlepass', seed=seed, **hp)
    return pd.concat([result_double, result_single])

# %%
from src.models import NNAlignWrapper
hyperparameters = dict(n_hidden=50, p_drop=0.4, batchnorm=True, window_size=6, activation=nn.ReLU(), batch_size=128, n_epochs=500, lr=1e-4, wd=1e-2)
singledouble = partial(singledouble_wrapper, dataset=pd.read_csv('../data/other/viral.csv').rename(columns={'sequence':'Peptide'}), hp=hyperparameters)
output = pd.concat(Parallel(n_jobs=7)(delayed(singledouble)(seed=seed) for seed in tqdm(range(100), desc='seed')))

output_gb = output.groupby(['identifier']).agg(mean_test_auc = ('best_test_auc','mean'),
                                   std_test_auc = ('best_test_auc', 'std'),
                                    mean_train_auc = ('best_train_auc','mean'),
                                  mean_time = ('elapsed_seconds', 'mean'))
# Out:
# seed:   0%|          | 0/100 [00:00<?, ?it/s]
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s].74it/s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:  90%|█████████ | 452/500 [01:03<00:06,  7.26it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:55,  8.93it/s]s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:  91%|█████████ | 453/500 [01:04<00:06,  7.26it/s]
# Start training
# Before training
# Training epochs:  12%|█▏        | 59/500 [00:07<00:52,  8.33it/s]
# Start training
# Before training
# Training epochs:  13%|█▎        | 65/500 [00:07<00:52,  8.26it/s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:  77%|███████▋  | 386/500 [00:52<00:15,  7.35it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:09,  7.18it/s]s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:   2%|▏         | 10/500 [00:01<01:06,  7.34it/s]]
# Start training
# Before training
# Training epochs:  24%|██▍       | 120/500 [00:15<00:45,  8.36it/s]
# Start training
# Before training
# Training epochs:  27%|██▋       | 133/500 [00:16<00:46,  7.87it/s]
# Start training
# Before training
# Training epochs:  26%|██▌       | 128/500 [00:16<00:47,  7.82it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 7.96it/s]
# Start training
# Before training
# Training epochs:  69%|██████▊   | 343/500 [00:48<00:21,  7.14it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:55,  9.02it/s]s]
# Start training
# Before training
# Training epochs:   1%|▏         | 7/500 [00:00<00:59,  8.34it/s]]]
# Start training
# Before training
# Training epochs: 100%|█████████▉| 498/500 [01:10<00:00,  6.51it/s]
# Start training
# Before training
# Training epochs:  38%|███▊      | 188/500 [00:22<00:39,  7.88it/s]
# Start training
# Before training
# Training epochs:   1%|          | 3/500 [00:00<01:10,  7.03it/s]s]
# Start training
# Before training
# Training epochs:  98%|█████████▊| 492/500 [00:59<00:00,  8.11it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:57,  8.64it/s]s]
# Start training
# Before training
# Training epochs:  54%|█████▍    | 272/500 [00:37<00:31,  7.18it/s]
# Start training
# Before training
# Training epochs:  57%|█████▋    | 285/500 [00:38<00:29,  7.37it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:09,  7.17it/s]s]
# Start training
# Before training
# Training epochs:  49%|████▉     | 244/500 [00:30<00:35,  7.20it/s]
# Start training
# Before training
# Training epochs:   4%|▍         | 20/500 [00:02<01:05,  7.33it/s]]
# Start training
# Before training
# Training epochs:  99%|█████████▉| 495/500 [01:02<00:00,  8.10it/s]
# Start training
# Before training
# Training epochs:  43%|████▎     | 217/500 [00:30<00:39,  7.22it/s]
# Start training
# Before training
# Training epochs:  49%|████▊     | 243/500 [00:34<00:35,  7.18it/s]
# Start training
# Before training
# Training epochs:  45%|████▍     | 223/500 [00:31<00:40,  6.85it/s]
# Start training
# Before training
# Training epochs:  60%|██████    | 301/500 [00:36<00:24,  8.12it/s]
# Start training
# Before training
# Training epochs:  63%|██████▎   | 315/500 [00:37<00:21,  8.43it/s]
# Start training
# Before training
# Training epochs:   3%|▎         | 16/500 [00:02<01:05,  7.33it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:02,  7.98it/s]s]
# Start training
# Before training
# Training epochs:  34%|███▍      | 169/500 [00:22<00:45,  7.27it/s]
# Start training
# Before training
# Training epochs:   3%|▎         | 17/500 [00:02<01:00,  8.01it/s]]
# Start training
# Before training
# Training epochs:   1%|          | 4/500 [00:00<01:01,  8.08it/s]]]
# Start training
# Before training
# Training epochs:  72%|███████▏  | 359/500 [00:44<00:19,  7.17it/s]
# Start training
# Before training
# Training epochs:  77%|███████▋  | 386/500 [00:48<00:14,  8.11it/s]
# Start training
# Before training
# Training epochs:   3%|▎         | 14/500 [00:01<01:08,  7.07it/s]]
# Start training
# Before training
# Training epochs:  18%|█▊        | 92/500 [00:13<00:58,  7.01it/s]]
# Start training
# Before training
# Training epochs:  22%|██▏       | 109/500 [00:15<00:56,  6.95it/s]
# Start training
# Before training
# Training epochs:  99%|█████████▉| 497/500 [01:03<00:00,  7.28it/s]
# Start training
# Before training
# Training epochs:   2%|▏         | 11/500 [00:01<01:02,  7.79it/s]]
# Start training
# Before training
# Training epochs:  92%|█████████▏| 460/500 [00:55<00:05,  7.89it/s]
# Start training
# Before training
# Training epochs:   2%|▏         | 8/500 [00:01<01:09,  7.04it/s]s]
# Start training
# Before training
# Training epochs:  92%|█████████▏| 460/500 [00:56<00:04,  8.17it/s]
# Start training
# Before training
# Training epochs:   8%|▊         | 40/500 [00:05<01:04,  7.17it/s]]
# Start training
# Before training
# Training epochs:  98%|█████████▊| 492/500 [01:00<00:00,  8.28it/s]
# Start training
# Before training
# Training epochs:   5%|▍         | 24/500 [00:03<00:59,  8.04it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:56,  8.87it/s]]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 467/500 [00:58<00:04,  7.65it/s]
# Start training
# Before training
# Training epochs:   2%|▏         | 9/500 [00:01<01:01,  8.05it/s]s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:   2%|▏         | 8/500 [00:00<00:58,  8.36it/s]]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]7.23it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:10,  7.08it/s]]
# Start training
# Before training
# Start training
# Before training
# Training epochs:  84%|████████▍ | 422/500 [00:59<00:11,  6.80it/s]
# Start training
# Before training
# Training epochs:  98%|█████████▊| 489/500 [00:59<00:01,  8.33it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:06,  7.46it/s]]]
# Start training
# Before training
# Training epochs:   7%|▋         | 35/500 [00:04<00:57,  8.08it/s]]
# Start training
# Before training
# Training epochs:   9%|▉         | 44/500 [00:05<01:04,  7.02it/s]]
# Start training
# Before training
# Training epochs:  19%|█▉        | 97/500 [00:12<00:50,  8.05it/s]]
# Start training
# Before training
# Training epochs:  20%|██        | 101/500 [00:13<00:52,  7.53it/s]
# Start training
# Before training
# Training epochs:  74%|███████▍  | 370/500 [00:51<00:18,  7.18it/s]
# Start training
# Before training
# Training epochs:   3%|▎         | 17/500 [00:02<00:56,  8.59it/s]]
# Start training
# Before training
# Training epochs:   8%|▊         | 38/500 [00:04<00:56,  8.19it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:53,  9.26it/s]s]
# Start training
# Before training
# Training epochs:  99%|█████████▉| 496/500 [01:09<00:00,  7.52it/s]
# Start training
# Before training
# Training epochs:  23%|██▎       | 117/500 [00:14<00:50,  7.61it/s]
# Start training
# Before training
# Training epochs:   7%|▋         | 35/500 [00:04<01:10,  6.63it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 7.10it/s]
# Start training
# Before training
# Training epochs:  97%|█████████▋| 484/500 [00:59<00:01,  8.06it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<00:59,  8.37it/s]s]
# Start training
# Before training
# Training epochs:  13%|█▎        | 65/500 [00:08<00:53,  8.06it/s]]
# Start training
# Before training
# Training epochs:  40%|████      | 200/500 [00:25<00:37,  7.90it/s]
# Start training
# Before training
# Training epochs:  35%|███▍      | 174/500 [00:22<00:44,  7.38it/s]
# Start training
# Before training
# Training epochs:  56%|█████▌    | 279/500 [00:34<00:28,  7.75it/s]
# Start training
# Before training
# Training epochs:  87%|████████▋ | 435/500 [00:55<00:08,  7.74it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 466/500 [00:58<00:04,  8.02it/s]
# Start training
# Before training
# Training epochs:  98%|█████████▊| 489/500 [01:01<00:01,  7.99it/s]
# Start training
# Before training
# Training epochs:  63%|██████▎   | 316/500 [00:43<00:27,  6.78it/s]
# Start training
# Before training
# Training epochs:  99%|█████████▉| 494/500 [01:08<00:00,  7.58it/s]
# Start training
# Before training
# Training epochs:   2%|▏         | 11/500 [00:01<01:08,  7.10it/s]]
# Start training
# Before training
# Training epochs:  58%|█████▊    | 289/500 [00:35<00:25,  8.19it/s]
# Start training
# Before training
# Training epochs:  33%|███▎      | 163/500 [00:23<00:49,  6.78it/s]
# Start training
# Before training
# Training epochs:  41%|████▏     | 207/500 [00:29<00:41,  7.00it/s]
# Start training
# Before training
# Training epochs:  44%|████▍     | 220/500 [00:31<00:41,  6.80it/s]
# Start training
# Before training
# Training epochs:  16%|█▋        | 82/500 [00:10<00:51,  8.07it/s]]
# Start training
# Before training
# Training epochs:  57%|█████▋    | 287/500 [00:37<00:27,  7.86it/s]
# Start training
# Before training
# Training epochs:  71%|███████   | 353/500 [00:44<00:19,  7.67it/s]
# Start training
# Before training
# Training epochs:  85%|████████▍ | 424/500 [00:54<00:09,  7.80it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:00,  8.23it/s]]]
# Start training
# Before training
# Training epochs:  21%|██        | 105/500 [00:15<00:54,  7.19it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]8.05it/s]]
# Start training
# Before training
# Training epochs:  30%|██▉       | 149/500 [00:21<00:51,  6.87it/s]
# Start training
# Before training
# Training epochs:  90%|█████████ | 451/500 [01:03<00:07,  6.71it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 467/500 [01:06<00:04,  7.14it/s]
# Start training
# Before training
# Training epochs: 100%|█████████▉| 498/500 [01:01<00:00,  7.84it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 7.73it/s]
# Start training
# Before training
# Training epochs:   7%|▋         | 37/500 [00:05<01:07,  6.91it/s]]
# Start training
# Before training
# Training epochs:  13%|█▎        | 65/500 [00:08<00:56,  7.76it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 6.93it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 464/500 [00:58<00:04,  8.00it/s]
# Start training
# Before training
# Training epochs:  90%|█████████ | 452/500 [01:04<00:07,  6.81it/s]
# Start training
# Before training
# Training epochs:  91%|█████████ | 453/500 [00:57<00:06,  7.77it/s]
# Start training
# Before training
# Training epochs:   4%|▍         | 19/500 [00:02<01:04,  7.50it/s]]
# Start training
# Before training
# Training epochs:   5%|▌         | 27/500 [00:03<00:58,  8.14it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]7.56it/s]]
# Start training
# Before training
# Training epochs:  21%|██        | 104/500 [00:14<00:53,  7.41it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 8.35it/s]
# Start training
# Before training
# Training epochs:  85%|████████▍ | 423/500 [00:52<00:09,  8.22it/s]
# Start training
# Before training
# Training epochs:   6%|▌         | 28/500 [00:03<00:59,  7.95it/s]]
# Start training
# Before training
# Training epochs:  15%|█▌        | 76/500 [00:09<00:50,  8.35it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:09,  7.22it/s]s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:01,  8.09it/s]]]
# Start training
# Before training
# Training epochs:   4%|▍         | 21/500 [00:02<01:00,  7.95it/s]]
# Start training
# Before training
# Training epochs:  74%|███████▍  | 372/500 [00:53<00:18,  6.91it/s]
# Start training
# Before training
# Training epochs:  92%|█████████▏| 462/500 [00:58<00:04,  7.71it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 465/500 [01:06<00:05,  6.79it/s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:  10%|▉         | 49/500 [00:05<00:59,  7.59it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]7.30it/s]]
# Start training
# Before training
# Training epochs:  42%|████▏     | 211/500 [00:24<00:34,  8.38it/s]
# Start training
# Before training
# Training epochs:  61%|██████    | 305/500 [00:41<00:27,  6.96it/s]
# Start training
# Before training
# Training epochs:   6%|▌         | 29/500 [00:03<01:00,  7.84it/s]]
# Start training
# Before training
# Training epochs:  11%|█         | 54/500 [00:06<00:55,  8.01it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 7.39it/s]
# Start training
# Before training
# Training epochs:  32%|███▏      | 161/500 [00:20<00:40,  8.42it/s]
# Start training
# Before training
# Training epochs:   6%|▌         | 30/500 [00:04<01:07,  7.01it/s]]
# Start training
# Before training
# Training epochs:  15%|█▍        | 74/500 [00:11<01:31,  4.68it/s]]
# Start training
# Before training
# Training epochs:  85%|████████▍ | 423/500 [00:55<00:09,  7.77it/s]
# Start training
# Before training
# Training epochs:  82%|████████▏ | 410/500 [00:53<00:11,  8.02it/s]
# Start training
# Before training
# Training epochs:  11%|█         | 55/500 [00:06<00:56,  7.89it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 7.74it/s]
# Start training
# Before training
# Training epochs:  85%|████████▌ | 427/500 [01:01<00:10,  7.20it/s]
# Start training
# Before training
# Training epochs:  60%|██████    | 300/500 [00:36<00:23,  8.52it/s]
# Start training
# Before training
# Training epochs:  16%|█▋        | 82/500 [00:11<00:56,  7.34it/s]]
# Start training
# Before training
# Training epochs:  73%|███████▎  | 366/500 [00:44<00:16,  8.14it/s]
# Start training
# Before training
# Training epochs:  49%|████▉     | 246/500 [00:33<00:34,  7.38it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]8.03it/s]]
# Start training
# Before training
# Training epochs:  61%|██████    | 305/500 [00:41<00:27,  7.07it/s]
# Start training
# Before training
# Training epochs:  46%|████▌     | 229/500 [00:28<00:33,  8.11it/s]
# Start training
# Before training
# Training epochs:  72%|███████▏  | 362/500 [00:44<00:17,  7.94it/s]
# Start training
# Before training
# Training epochs:  65%|██████▌   | 327/500 [00:41<00:22,  7.83it/s]
# Start training
# Before training
# Training epochs:  26%|██▌       | 130/500 [00:18<00:50,  7.30it/s]
# Start training
# Before training
# Training epochs:  22%|██▏       | 109/500 [00:15<00:55,  7.03it/s]
# Start training
# Before training
# Training epochs:  12%|█▏        | 62/500 [00:07<00:52,  8.32it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 8.45it/s]
# Start training
# Before training
# Training epochs:  73%|███████▎  | 365/500 [00:43<00:16,  7.96it/s]
# Start training
# Before training
# Training epochs:  89%|████████▉ | 444/500 [00:53<00:06,  8.39it/s]
# Start training
# Before training
# Training epochs:  69%|██████▉   | 344/500 [00:42<00:18,  8.35it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s].52it/s]s]
# Start training
# Before training
# Training epochs:  88%|████████▊ | 439/500 [00:53<00:07,  8.20it/s]
# Start training
# Before training
# Training epochs:  19%|█▉        | 97/500 [00:13<00:54,  7.36it/s]]
# Start training
# Before training
# Training epochs:  31%|███       | 154/500 [00:20<00:44,  7.83it/s]
# Start training
# Before training
# Training epochs:  82%|████████▏ | 411/500 [00:55<00:11,  7.63it/s]
# Start training
# Before training
# Training epochs:  94%|█████████▎| 468/500 [01:02<00:04,  7.61it/s]
# Start training
# Before training
# Training epochs:   1%|          | 4/500 [00:00<01:11,  6.92it/s]s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 8.27it/s]
# Start training
# Before training
# Training epochs:   3%|▎         | 17/500 [00:01<00:56,  8.61it/s]]
# Start training
# Before training
# Training epochs:  90%|█████████ | 450/500 [00:59<00:07,  6.77it/s]
# Start training
# Before training
# Training epochs:  39%|███▉      | 196/500 [00:27<00:43,  7.06it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 463/500 [00:55<00:04,  8.56it/s]
# Start training
# Before training
# Training epochs:  79%|███████▉  | 397/500 [00:56<00:14,  7.07it/s]
# Start training
# Before training
# Training epochs:  95%|█████████▍| 473/500 [01:06<00:03,  6.86it/s]
# Start training
# Before training
# Training epochs:  83%|████████▎ | 416/500 [00:50<00:10,  8.00it/s]
# Start training
# Before training
# Training epochs:  22%|██▏       | 110/500 [00:13<00:48,  8.09it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:18,  6.35it/s]]]
# Start training
# Before training
# Training epochs:  12%|█▏        | 61/500 [00:07<00:55,  7.95it/s]]
# Start training
# Before training
# Training epochs:  86%|████████▌ | 429/500 [00:59<00:09,  7.31it/s]
# Start training
# Before training
# Training epochs:  10%|█         | 52/500 [00:06<00:57,  7.78it/s]]
# Start training
# Before training
# Training epochs:  18%|█▊        | 91/500 [00:11<00:52,  7.86it/s]]
# Start training
# Before training
# Training epochs:   5%|▌         | 25/500 [00:03<01:18,  6.05it/s]]
# Start training
# Before training
# Training epochs:  18%|█▊        | 90/500 [00:10<00:46,  8.80it/s]]
# Start training
# Before training
# Training epochs:  13%|█▎        | 64/500 [00:07<00:53,  8.10it/s]]
# Start training
# Before training
# Training epochs:  19%|█▉        | 95/500 [00:11<00:49,  8.20it/s]]
# Start training
# Before training
# Training epochs:  76%|███████▌  | 381/500 [00:46<00:13,  8.85it/s]
# Start training
# Before training
# Training epochs:  74%|███████▍  | 369/500 [00:45<00:16,  7.87it/s]
# Start training
# Before training
# Training epochs:  70%|███████   | 350/500 [00:50<00:24,  6.06it/s]
# Start training
# Before training
# Training epochs:  93%|█████████▎| 465/500 [01:06<00:04,  7.12it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:01,  8.11it/s]]]
# Start training
# Before training
# Training epochs:  20%|█▉        | 98/500 [00:12<00:54,  7.34it/s]]
# Start training
# Before training
# Training epochs:  22%|██▏       | 112/500 [00:16<00:56,  6.83it/s]
# Start training
# Before training
# Training epochs:  64%|██████▍   | 320/500 [00:41<00:23,  7.75it/s]
# Start training
# Before training
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s] 8.14it/s]
# Start training
# Before training
# Training epochs:  26%|██▌       | 131/500 [00:16<00:46,  7.87it/s]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:26,  5.76it/s]s]
# Start training
# Before training
# Training epochs:   9%|▉         | 46/500 [00:05<00:54,  8.40it/s]]
# Start training
# Before training
# Start training
# Before training

# %%
output_gb.to_csv('../output/230522_singledouble_compare/single_double_comparison_gb.csv')
output.to_csv('../output/230522_singledouble_compare/single_double_comparison_all.csv')

# %%
output_gb
# Out:
#           identifier  mean_test_auc  std_test_auc  mean_train_auc  mean_time
# 0  normal_doublepass       0.673933      0.021110        0.753256      66.24
# 1    test_singlepass       0.672833      0.022561        0.765367      63.69

# %% [markdown]
# ## neoepitopes

# %%
from sklearn.metrics import roc_auc_score

# %%
neoepi_train, neoepi_test = train_test_split(cedar_aligned, test_size=1/5, random_state=13)
neoepi_train.to_csv('../../nnalign_cedar/df_train_neoepi_pynncompare.txt', columns = ['Peptide', 'agg_label'], index=False, header=False, sep='\t')
neoepi_test.to_csv('../../nnalign_cedar/df_test_neoepi_pynncompare.txt', columns = ['Peptide','agg_label'], index=False, header=False,sep='\t')

# %%
from src.models import NNAlignWrapper

hyperparameters = dict(n_hidden=50, p_drop=0., batchnorm=False, window_size=6, activation=nn.ReLU(), batch_size=64, n_epochs=500, lr=1e-4, wd=1e-30, singlepass=True)
run_wrapper = partial(run, df_train=neoepi_train, df_test=neoepi_test, model_constructor=NNAlignWrapper,encoding= 'BL50LO', id_='neoepi', outdir='230522_impl_comparisons/', **hyperparameters)

output_neoepi = pd.concat(Parallel(n_jobs=1)(delayed(run_wrapper)(seed=seed) for seed in tqdm(range(30),desc='seed')))
# result_simple = run(df_train, df_test, NNAlignWrapper, 'BL50LO', id_='neoepi', outdir='230522_impl_comparisons/', **hyperparameters)
neoepi_gb = output_neoepi.groupby(['identifier']).agg(mean_train_auc=('best_train_auc','mean'),
                                          mean_test_auc=('best_test_auc', 'mean'),
                                          mean_train_auc_idx=('best_train_auc_idx', 'mean'),
                                          mean_test_auc_idx=('best_test_auc_idx', 'mean'),
                                          mean_time = ('elapsed_seconds','mean'))
neoepi_gb
# Out:
# seed:   0%|          | 0/30 [00:00<?, ?it/s]
# Before training
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# Training epochs:   0%|          | 0/500 [00:00<?, ?it/s]
# Start training
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# ...
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([58, 7, 120])
# torch.Size([58, 7, 50])
# torch.Size([58, 7, 1])
# torch.Size([58, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([31, 7, 120])
# torch.Size([31, 7, 50])
# torch.Size([31, 7, 1])
# torch.Size([31, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# torch.Size([64, 7, 120])
# torch.Size([64, 7, 50])
# torch.Size([64, 7, 1])
# torch.Size([64, 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [71], in <cell line: 6>()
#       3 hyperparameters = dict(n_hidden=50, p_drop=0., batchnorm=False, window_size=6, activation=nn.ReLU(), batch_size=64, n_epochs=500, lr=1e-4, wd=1e-30, singlepass=True)
#       4 run_wrapper = partial(run, df_train=neoepi_train, df_test=neoepi_test, model_constructor=NNAlignWrapper,encoding= 'BL50LO', id_='neoepi', outdir='230522_impl_comparisons/', **hyperparameters)
# ----> 6 output_neoepi = pd.concat(Parallel(n_jobs=1)(delayed(run_wrapper)(seed=seed) for seed in tqdm(range(30),desc='seed')))
#       7 # result_simple = run(df_train, df_test, NNAlignWrapper, 'BL50LO', id_='neoepi', outdir='230522_impl_comparisons/', **hyperparameters)
#       8 neoepi_gb = output_neoepi.groupby(['identifier']).agg(mean_train_auc=('best_train_auc','mean'),
#       9                                           mean_test_auc=('best_test_auc', 'mean'),
#      10                                           mean_train_auc_idx=('best_train_auc_idx', 'mean'),
#      11                                           mean_test_auc_idx=('best_test_auc_idx', 'mean'),
#      12                                           mean_time = ('elapsed_seconds','mean'))
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# Input In [6], in run(df_train, df_test, model_constructor, encoding, n_hidden, window_size, p_drop, batchnorm, activation, batch_size, n_epochs, lr, wd, id_, outdir, seed, singlepass)
#      32 for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
#      33     if e==1:print('Start training')
# ---> 34     loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
#      35     train_losses.append(loss)
#      36     train_aucs.append(metrics['auc'])
#
# File ~/Documents/code/PyNNalign/src/train_eval.py:104, in train_model_step(model, criterion, optimizer, train_loader)
#     102 optimizer.zero_grad()
#     103 loss.backward()
# --> 104 optimizer.step()
#     105 y_true.append(y_train)
#     106 y_scores.append(F.sigmoid(output))
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:157, in Adam.step(self, closure)
#     153                 max_exp_avg_sqs.append(state['max_exp_avg_sq'])
#     155             state_steps.append(state['step'])
# --> 157     adam(params_with_grad,
#     158          grads,
#     159          exp_avgs,
#     160          exp_avg_sqs,
#     161          max_exp_avg_sqs,
#     162          state_steps,
#     163          amsgrad=group['amsgrad'],
#     164          beta1=beta1,
#     165          beta2=beta2,
#     166          lr=group['lr'],
#     167          weight_decay=group['weight_decay'],
#     168          eps=group['eps'],
#     169          maximize=group['maximize'],
#     170          foreach=group['foreach'],
#     171          capturable=group['capturable'])
#     173 return loss
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:213, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     210 else:
#     211     func = _single_tensor_adam
# --> 213 func(params,
#     214      grads,
#     215      exp_avgs,
#     216      exp_avg_sqs,
#     217      max_exp_avg_sqs,
#     218      state_steps,
#     219      amsgrad=amsgrad,
#     220      beta1=beta1,
#     221      beta2=beta2,
#     222      lr=lr,
#     223      weight_decay=weight_decay,
#     224      eps=eps,
#     225      maximize=maximize,
#     226      capturable=capturable)
#
# File ~/opt/anaconda3/envs/phd/lib/python3.10/site-packages/torch/optim/adam.py:305, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     303     denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     304 else:
# --> 305     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     307 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
neoepi_gb
# Out:
#             mean_train_auc  mean_test_auc  mean_train_auc_idx  \
# identifier
# neoepi            0.936913       0.719687          498.833333
#
#             mean_test_auc_idx  mean_time
# identifier
# neoepi             379.633333       13.2

# %%
# Predictions from Webserver : 
neoepi_preds_ws = pd.read_csv('../output/230522_impl_comparisons/neoepi_compare_2683455.evalset.txt', sep='\t')
neoepi_preds_ws['label'] = neoepi_preds_ws.Measure.astype(int)
roc_auc_score(neoepi_preds_ws['label'].values, neoepi_preds_ws['Prediction'].values)
# Out:
# 0.6874202109789693

# %%
# Predictions from commandline : 
neoepi_preds_cl = pd.read_csv('../../nnalign_cedar/pynn_compare/output/neoepi_compare_28720/neoepi_compare_28720.evalset.txt', sep='\t')
neoepi_preds_cl['label'] = neoepi_preds_cl.Measure.astype(int)
roc_auc_score(neoepi_preds_cl['label'].values, neoepi_preds_cl['Prediction'].values)
# Out:
# 0.6874202109789693

# %% [markdown]
# ## virus

# %%
viral_train, viral_test = train_test_split(viral, test_size=1/10, random_state=13)
viral_train.to_csv('../../nnalign_cedar/df_train_viral_pynncompare.txt', columns = ['Peptide', 'agg_label'], index=False, header=False, sep='\t')
viral_test.to_csv('../../nnalign_cedar/df_test_viral_pynncompare.txt', columns = ['Peptide','agg_label'], index=False, header=False,sep='\t')

# %%
from src.models import NNAlign

hyperparameters = dict(n_hidden=50, p_drop=0., batchnorm=False, window_size=6, activation=nn.ReLU(), batch_size=64, n_epochs=500, lr=1e-4, wd=0, singlepass=True)
run_wrapper = partial(run, df_train=viral_train, df_test=viral_test, model_constructor=NNAlign,encoding= 'BL50LO', id_='neoepi', outdir='230522_impl_comparisons/', **hyperparameters)

output_viral = Parallel(n_jobs=7)(delayed(run_wrapper)(seed=seed) for seed in tqdm(range(30),desc='seed'))
# Out:
# seed:   0%|          | 0/30 [00:00<?, ?it/s]
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Start training
# Before training
# Training epochs:   4%|▍         | 21/500 [00:03<01:08,  7.02it/s]
# Before training
# Training epochs:  98%|█████████▊| 488/500 [01:07<00:01,  7.60it/s]
# Start training
# Before training
# Training epochs:   4%|▍         | 19/500 [00:02<01:05,  7.29it/s]]
# Start training
# Before training
# Start training
# Before training
# Training epochs:   4%|▍         | 22/500 [00:03<01:05,  7.35it/s]]
# Start training
# Before training
# Training epochs:   1%|          | 6/500 [00:00<01:04,  7.65it/s]s]
# Start training
# Before training
# Training epochs:   2%|▏         | 8/500 [00:01<01:02,  7.90it/s]]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:06,  7.52it/s]]]
# Start training
# Before training
# Training epochs:  95%|█████████▌| 477/500 [01:01<00:03,  7.23it/s]
# Start training
# Before training
# Training epochs:  73%|███████▎  | 364/500 [00:54<00:21,  6.30it/s]
# Start training
# Before training
# Training epochs: 100%|█████████▉| 499/500 [01:04<00:00,  7.67it/s]
# Start training
# Before training
# Training epochs:   1%|          | 5/500 [00:00<01:03,  7.77it/s]]
# Start training
# Before training
# Start training
# Before training
# Training epochs:   2%|▏         | 11/500 [00:01<01:15,  6.48it/s]]
# Start training
# Before training
# Training epochs:  34%|███▍      | 169/500 [00:25<00:55,  6.02it/s]
# Start training
# Before training
# Training epochs:  95%|█████████▌| 477/500 [01:07<00:03,  6.56it/s]
# Start training
# Before training
# Training epochs:  55%|█████▌    | 277/500 [00:46<00:34,  6.44it/s]
# Start training
# Before training
# Training epochs:   1%|▏         | 7/500 [00:00<01:10,  6.97it/s]s]
# Start training
# Before training
# Start training
# Before training
# Training epochs:   1%|▏         | 7/500 [00:00<01:06,  7.39it/s]]]
# Start training
# Before training
# Training epochs:   2%|▏         | 12/500 [00:01<01:05,  7.42it/s]]
# Start training
# Before training
# Training epochs:   0%|          | 1/500 [00:00<01:13,  6.81it/s]s]
# Start training
# Before training
# Training epochs:  97%|█████████▋| 486/500 [01:07<00:01,  7.07it/s]
# Start training
# Before training
# Training epochs:  97%|█████████▋| 484/500 [01:09<00:02,  6.96it/s]
# Start training
# Before training

# %%
viral_gb = pd.concat(output_viral).groupby(['identifier']).agg(mean_train_auc=('best_train_auc','mean'),
                                                    mean_test_auc=('best_test_auc', 'mean'),
                                                    mean_train_auc_idx=('best_train_auc_idx', 'mean'),
                                                    mean_test_auc_idx=('best_test_auc_idx', 'mean'),
                                                    mean_time = ('elapsed_seconds','mean'))
viral_gb
# Out:
#             mean_train_auc  mean_test_auc  mean_train_auc_idx  \
# identifier
# neoepi            0.916443       0.815427               499.0
#
#             mean_test_auc_idx  mean_time
# identifier
# neoepi                  488.6  68.666667

# %%
from sklearn.metrics import roc_auc_score
# Predictions from Webserver : 
viral_preds_ws = pd.read_csv('../output/230522_impl_comparisons/Viral_compare_2750517.evalset.txt', sep='\t')
viral_preds_ws['label'] = viral_preds_ws.Measure.astype(int)
roc_auc_score(viral_preds_ws['label'].values, viral_preds_ws['Prediction'].values)
# Out:
# 0.7885790692920897

# %%
# Predictions from commandline : 
viral_preds_cl = pd.read_csv('../../nnalign_cedar/pynn_compare/output/viral_compare_30030/viral_compare_30030.evalset.txt', sep='\t')
viral_preds_cl['label'] = viral_preds_cl.Measure.astype(int)
roc_auc_score(viral_preds_cl['label'].values, viral_preds_cl['Prediction'].values)
# Out:
# 0.7885790692920897

# %%
viral_gb.to_csv('../output/230522_impl_comparisons/viral_gb_nodrop_nobatchnorm_nowd.csv', index=False)
neoepi_gb.to_csv('../output/230522_impl_comparisons/neoepi_gb_nodrop_nobatchnorm_nowd.csv', index=False)

# %%
anchor = 595+176
nonanch = 1702+444
sum_ = anchor+nonanch

nonanch/sum_
# Out:
# 0.7356873500171409

# %% [markdown]
# # decode code test

# %%
from src.data_processing import BL50_VALUES, BL62FREQ_VALUES, BL62_VALUES, CHAR_TO_INT, INT_TO_CHAR, encoding_matrix_dict, encode_batch

# %%
def decode(tensor, window_size, max_len, encoding='onehot', blosum_matrix=None):
    """
    Decodes a PyTorch tensor back to the original sequences.
    """
    assert encoding in encoding_matrix_dict.keys(), f'Wrong encoding key {encoding} passed!'\
                                                    f'Should be any of {encoding_matrix_dict.keys()}'
    if encoding == 'onehot':
        # Fold the tensor back into the original shape
        tensor = tensor.view(-1, max_len, tensor.shape[-1])
        # Convert tensor to numpy array
        tensor_np = tensor.numpy()
        # Convert one-hot encoded vectors to integer values
        int_encoded = np.argmax(tensor_np, axis=-1)
        # Convert integer values to characters
        sequences = [''.join([INT_TO_CHAR[val] for val in row]) for row in int_encoded]
    else:
        if blosum_matrix is None or not isinstance(blosum_matrix, dict):
            raise Exception('No BLOSUM matrix provided!')
        # Fold the tensor back into the original shape
        tensor = tensor.view(-1, max_len, matrix_dim)
        # Convert tensor to numpy array
        tensor_np = tensor.numpy()
        # Convert BLOSUM encoded values to characters
        sequences = [''.join([get_blosum_char(row, blosum_matrix) for row in window]) for window in tensor_np]

    return sequences


def get_blosum_char(row, blosum_matrix):
    """
    Helper function to get the character corresponding to the BLOSUM encoded row.
    """
    for char, array in blosum_matrix.items():
        if np.array_equal(array, row):
            return char
    raise ValueError('No matching character found in the BLOSUM matrix!')

# %%
df_train, df_test = train_test_split(cedar_aligned, test_size=1/5, random_state=13)
train_loader, train_dataset = get_NNAlign_dataloader(df_train, 12, 6, 'BL50LO', return_dataset=True)
test_loader, test_dataset = get_NNAlign_dataloader(df_test, 12, 6, 'BL50LO', return_dataset=True)

sequences = df_test['Peptide'].values
assert (test_dataset[:][1].numpy().flatten() == df_test['agg_label'].values).all(), 'order not preserved!'
# Out:
# Pruning sequences longer than length=12.
# Nseqs Before:	2426
# Nseqs After:	2426
# Pruning sequences longer than length=12.
# Nseqs Before:	607
# Nseqs After:	607

# %%
import torch
from copy import deepcopy
batch_size = len(x_start)
# Assume you have a folded tensor with shape (batch_size, folded_dim, window_size, matrix_dim)
x_folded = x_reshaped.clone()

# Parameters for folding
original_dim = max_len  # The original dimension before folding

# Calculate the unfolded shape
unfolded_dim = original_dim - window_size + 1  # Calculate the unfolded dimension
unfolded_shape = (batch_size, unfolded_dim, window_size * matrix_dim)

# Unfold the tensor to its original shape
unfolded_tensor = x_folded.reshape(unfolded_shape).contiguous()
print(unfolded_tensor.shape)
# Out:
# torch.Size([10, 7, 120])

# %%
from src.models import Standardizer
std = Standardizer()
x1 = dataset[:5][0]
x2 = dataset[5:][0]

std.fit(x1)
x2_std = std(x2)
x2_recover = std.recover(x2_std)
(x2_recover.int().float().int()==x2.float().int()).all(), (x2_std==x2).all()
# Out:
# (tensor(False), tensor(False))

# %%
x2.__class__.__name__
# Out:
# 'Tensor'

# %% [markdown]
# # Save/Load

# %%
from src.models import *
df_train, df_test = train_test_split(cedar_aligned, test_size=1/5, random_state=13)
train_loader, train_dataset = get_NNAlign_dataloader(df_train, 12, 6, 'BL50LO', return_dataset=True)
test_loader, test_dataset = get_NNAlign_dataloader(df_test, 12, 6, 'BL50LO', return_dataset=True)

std = Standardizer()
std.fit(train_dataset[:][0])
# Out:
# Pruning sequences longer than length=12.
# Nseqs Before:	2426
# Nseqs After:	2426
# Pruning sequences longer than length=12.
# Nseqs Before:	607
# Nseqs After:	607

# %%
print(std.fitted, hasattr(std, 'state_dict'), std.mu[0:5], std.sigma[0:5])
save_checkpoint_single(std, 'stdzr.pt')
# Out:
# True True tensor([-0.6686, -1.4416, -1.2201, -1.7801, -2.0275]) tensor([1.8819, 2.4110, 2.3332, 2.6559, 2.2315])
# Model saved at ./stdzr.pt

# %%
std2=Standardizer()
std2.load_state_dict(torch.load('stdzr.pt'))
print(std2.fitted, hasattr(std2, 'state_dict'), std2.mu[0:5], std2.sigma[0:5])
# Out:
# True True tensor([-0.6686, -1.4416, -1.2201, -1.7801, -2.0275]) tensor([1.8819, 2.4110, 2.3332, 2.6559, 2.2315])

# %%
from src.models import NNAlignSinglePass
nnsp = NNAlignSinglePass(50, 6, indel=True)
save_checkpoint_single(nnsp, 'nnsp.pt')
nnsp.matrix_dim
# Out:
# Model saved at ./nnsp.pt
# 21

# %% [markdown]
# ## w/ standardizer

# %%
from src.models import NNAlign, NNAlignSinglePass, Standardizer

nnalign = NNAlign(50, 6, standardizer=True, singlepass=True)
nnalign.fit_standardizer(train_dataset[:100][0])
print(nnalign.standardizer.fitted, hasattr(nnalign.standardizer, 'state_dict'), nnalign.standardizer.mu[0:5], nnalign.standardizer.sigma[0:5], nnalign.init_params, nnalign.nnalign.in_layer.weight[0][:5])
# Out:
# True True tensor([-0.6014, -1.5086, -1.2843, -1.8243, -1.8600]) tensor([1.9784, 2.3763, 2.2784, 2.7031, 2.5615]) {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([ 0.0857,  0.0449,  0.0017, -0.0819, -0.0177], grad_fn=<SliceBackward0>)

# %%
save_checkpoint_single(nnalign, 'nnalign.pt')
nnalign2 = NNAlign(50, 6, standardizer=True, singlepass=True)
print(nnalign2.standardizer.fitted, hasattr(nnalign2.standardizer, 'state_dict'), nnalign2.standardizer.mu, nnalign2.standardizer.sigma, nnalign2.init_params, nnalign2.nnalign.in_layer.weight[0][:5])
nnalign2.load_state_dict(torch.load('nnalign.pt'))
print(nnalign2.standardizer.fitted, hasattr(nnalign2.standardizer, 'state_dict'), nnalign2.standardizer.mu[0:5], nnalign2.standardizer.sigma[0:5], nnalign2.init_params, nnalign2.nnalign.in_layer.weight[0][:5])
# Out:
# Model saved at ./nnalign.pt
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([-0.0878,  0.0763,  0.0909,  0.0680, -0.0654], grad_fn=<SliceBackward0>)
# True True tensor([-0.6014, -1.5086, -1.2843, -1.8243, -1.8600]) tensor([1.9784, 2.3763, 2.2784, 2.7031, 2.5615]) {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([ 0.0857,  0.0449,  0.0017, -0.0819, -0.0177], grad_fn=<SliceBackward0>)

# %%
from src.torch_utils import create_load_model, save_checkpoint, load_checkpoint

# %%
nnalign3 = NNAlign(50, 6, standardizer=True, singlepass=True)
print(nnalign3.standardizer.fitted, hasattr(nnalign3.standardizer, 'state_dict'), nnalign3.standardizer.mu, nnalign3.standardizer.sigma, nnalign3.init_params, nnalign3.nnalign.in_layer.weight[0][:5])
nnalign3 = load_checkpoint(nnalign3, 'nnalign.pt')
print(nnalign3.standardizer.fitted, hasattr(nnalign3.standardizer, 'state_dict'), nnalign3.standardizer.mu[0:5], nnalign3.standardizer.sigma[0:5], nnalign3.init_params, nnalign3.nnalign.in_layer.weight[0][:5])
# Out:
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([-0.0302, -0.0666, -0.0258,  0.0467, -0.0363], grad_fn=<SliceBackward0>)
# True True tensor([-0.6014, -1.5086, -1.2843, -1.8243, -1.8600]) tensor([1.9784, 2.3763, 2.2784, 2.7031, 2.5615]) {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([ 0.0857,  0.0449,  0.0017, -0.0819, -0.0177], grad_fn=<SliceBackward0>)

# %%
nnalign4 = create_load_model(NNAlign, 'nnalign.pt')
print(nnalign4.standardizer.fitted, hasattr(nnalign4.standardizer, 'state_dict'), nnalign4.standardizer.mu[0:5], nnalign4.standardizer.sigma[0:5], nnalign4.init_params, nnalign4.nnalign.in_layer.weight[0][:5])
# Out:
# True True tensor([-0.6014, -1.5086, -1.2843, -1.8243, -1.8600]) tensor([1.9784, 2.3763, 2.2784, 2.7031, 2.5615]) {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': True, 'singlepass': True} tensor([ 0.0857,  0.0449,  0.0017, -0.0819, -0.0177], grad_fn=<SliceBackward0>)

# %% [markdown]
# ## w/o standardizer

# %%
from src.models import NNAlign, NNAlignSinglePass, Standardizer

nnalign = NNAlign(50, 6, standardizer=False, singlepass=True)
nnalign.fit_standardizer(train_dataset[:100][0])
print(nnalign.standardizer.fitted, hasattr(nnalign.standardizer, 'state_dict'), nnalign.standardizer.mu, nnalign.standardizer.sigma, nnalign.init_params, nnalign.nnalign.in_layer.weight[0][:5])
# Out:
# True True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0536, -0.0219,  0.0816, -0.0339, -0.0824], grad_fn=<SliceBackward0>)

# %%
save_checkpoint_single(nnalign, 'nnalign.pt')
nnalign2 = NNAlign(50, 6, standardizer=False, singlepass=True)
print(nnalign2.standardizer.fitted, hasattr(nnalign2.standardizer, 'state_dict'), nnalign2.standardizer.mu, nnalign2.standardizer.sigma, nnalign2.init_params, nnalign2.nnalign.in_layer.weight[0][:5])
nnalign2.load_state_dict(torch.load('nnalign.pt'))
print(nnalign2.standardizer.fitted, hasattr(nnalign2.standardizer, 'state_dict'), nnalign2.standardizer.mu, nnalign2.standardizer.sigma, nnalign2.init_params, nnalign2.nnalign.in_layer.weight[0][:5])
# Out:
# Model saved at ./nnalign.pt
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0385, -0.0333, -0.0015,  0.0166,  0.0173], grad_fn=<SliceBackward0>)
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0536, -0.0219,  0.0816, -0.0339, -0.0824], grad_fn=<SliceBackward0>)

# %%
nnalign3 = NNAlign(50, 6, standardizer=False, singlepass=True)
print(nnalign3.standardizer.fitted, hasattr(nnalign3.standardizer, 'state_dict'), nnalign3.standardizer.mu, nnalign3.standardizer.sigma, nnalign3.init_params, nnalign3.nnalign.in_layer.weight[0][:5])
nnalign3 = load_checkpoint(nnalign3, 'nnalign.pt')
print(nnalign3.standardizer.fitted, hasattr(nnalign3.standardizer, 'state_dict'), nnalign3.standardizer.mu, nnalign3.standardizer.sigma, nnalign3.init_params, nnalign3.nnalign.in_layer.weight[0][:5])
# Out:
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0455,  0.0897,  0.0449,  0.0760, -0.0287], grad_fn=<SliceBackward0>)
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0536, -0.0219,  0.0816, -0.0339, -0.0824], grad_fn=<SliceBackward0>)

# %%
nnalign4 = create_load_model(NNAlign, 'nnalign.pt')
print(nnalign4.standardizer.fitted, hasattr(nnalign4.standardizer, 'state_dict'), nnalign4.standardizer.mu, nnalign4.standardizer.sigma, nnalign4.init_params, nnalign4.nnalign.in_layer.weight[0][:5])
# Out:
# False True 0 1 {'n_hidden': 50, 'window_size': 6, 'activation': ReLU(), 'batchnorm': False, 'dropout': 0.0, 'indel': False, 'standardizer': False, 'singlepass': True} tensor([ 0.0536, -0.0219,  0.0816, -0.0339, -0.0824], grad_fn=<SliceBackward0>)

# %% [markdown]
# all good.

# %% [markdown]
# # train / test loops

# %%
from sklearn.model_selection import KFold, train_test_split
from src.data_processing import AA_KEYS
def prune_aas(sequence):
    return any([x not in AA_KEYS for x in sequence])

# Quick data_prep/check
# Need to grab DRB1_0301
c000 = pd.read_csv('../data/NetMHCIIpan_train/c000_el', sep = ' ', header=None).rename(columns = {0:'Sequence', 1: 'target', 2:'HLA'}).drop(columns=[3])
c001 = pd.read_csv('../data/NetMHCIIpan_train/c001_el', sep = ' ', header=None).rename(columns = {0:'Sequence', 1: 'target', 2:'HLA'}).drop(columns=[3])
c002 = pd.read_csv('../data/NetMHCIIpan_train/c002_el', sep = ' ', header=None).rename(columns = {0:'Sequence', 1: 'target', 2:'HLA'}).drop(columns=[3])
c003 = pd.read_csv('../data/NetMHCIIpan_train/c003_el', sep = ' ', header=None).rename(columns = {0:'Sequence', 1: 'target', 2:'HLA'}).drop(columns=[3])
c004 = pd.read_csv('../data/NetMHCIIpan_train/c004_el', sep = ' ', header=None).rename(columns = {0:'Sequence', 1: 'target', 2:'HLA'}).drop(columns=[3])
drb = pd.concat([c000, c001, c002, c003, c004])
drb = drb.query('HLA.str.contains("DRB1_0301")')
drb['to_prune'] = drb['Sequence'].apply(prune_aas)
print(len(drb))
drb = drb.query('not to_prune')
print('after pruning', len(drb))
drb.to_csv('../data/NetMHCIIpan_train/drb1_0301.csv', index=False)
# Out:
# 23252
# after pruning 23250

# %%
from src.utils import get_kfolds
drb = get_kfolds(drb, 5, 'Sequence', 'target')
for f in drb.fold.unique():
    drb.query('fold==@f').to_csv(f'../data/NetMHCIIpan_train/drb1_0301_f{f}.csv', index=False)
drb.groupby(['fold', 'target']).count()
drb.to_csv('../data/NetMHCIIpan_train/drb1_0301.csv', index=False)

# %%
drb = pd.read_csv('../data/NetMHCIIpan_train/drb1_0301.csv')
drb['len']=drb['Sequence'].apply(len)
drb.len.max(), drb.head()
# Out:
# (21,
#                  Sequence  target                       HLA  to_prune  len  \
#  0  AAQLAIRVTNPNARLRSEENE       1  Abelin__MAPTAC_DRB1_0301     False   21
#  1     AASSLTVDVTPPTAKAPT       1  Abelin__MAPTAC_DRB1_0301     False   18
#  2     ADKARKKLLADQAEARRS       1  Abelin__MAPTAC_DRB1_0301     False   18
#  3   ADKARKKLLADQAEARRSKT       1  Abelin__MAPTAC_DRB1_0301     False   20
#  4    AENLEQLIDQKLKDYEDLR       1  Abelin__MAPTAC_DRB1_0301     False   19
#
#     fold
#  0     0
#  1     0
#  2     0
#  3     0
#  4     0  )

# %%
out.groupby([ 'std',
'n_hidden',
'drop',
'batchnorm',
'batchsize',
'act',
'encoding']).agg(best_valid_auc = ('best_valid_auc', 'max'),
                 best_test_auc = ('best_test_auc', 'max'),
                best_prime_auc= ('best_prime_auc','max')).sort_values('best_prime_auc', ascending=False).head(10)
# Out:
#                                                        best_valid_auc  \
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ          0.7248
# False 25       0.0  True      64        SELU BL50LO            0.7582
# True  10       0.3  True      64        ReLU BL62FREQ          0.7331
# False 25       0.3  False     128       ReLU BL50LO            0.7367
# True  50       0.0  False     64        ReLU BL50LO            0.7737
# False 10       0.0  False     128       SELU BL50LO            0.7278
#       25       0.3  True      128       SELU BL62LO            0.7293
# True  25       0.0  False     64        SELU BL62LO            0.7504
#       10       0.3  False     64        SELU BL62LO            0.7306
#       25       0.0  False     128       ReLU BL62LO            0.7271
#
#                                                        best_test_auc  \
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ         0.6569
# False 25       0.0  True      64        SELU BL50LO           0.6849
# True  10       0.3  True      64        ReLU BL62FREQ         0.6429
# False 25       0.3  False     128       ReLU BL50LO           0.6488
# True  50       0.0  False     64        ReLU BL50LO           0.7030
# False 10       0.0  False     128       SELU BL50LO           0.6692
#       25       0.3  True      128       SELU BL62LO           0.6657
# True  25       0.0  False     64        SELU BL62LO           0.6797
#       10       0.3  False     64        SELU BL62LO           0.6634
#       25       0.0  False     128       ReLU BL62LO           0.6201
#
#                                                        best_prime_auc
# std   n_hidden drop batchnorm batchsize act  encoding
# True  50       0.0  False     64        ReLU BL62FREQ          0.6975
# False 25       0.0  True      64        SELU BL50LO            0.6877
# True  10       0.3  True      64        ReLU BL62FREQ          0.6874
# False 25       0.3  False     128       ReLU BL50LO            0.6797
# True  50       0.0  False     64        ReLU BL50LO            0.6764
# False 10       0.0  False     128       SELU BL50LO            0.6744
#       25       0.3  True      128       SELU BL62LO            0.6727
# True  25       0.0  False     64        SELU BL62LO            0.6707
#       10       0.3  False     64        SELU BL62LO            0.6686
#       25       0.0  False     128       ReLU BL62LO            0.6677

# %%
-f "../data/NetMHCIIpan_train/drb1_0301.csv" -kf 0 -enc "BL50LO" -ml 21 -pad -15 -nh 50 -std True -bn True -do 0.0 -ws 9 -bs 256 -ne 500 -tol 1e-4

# %%
    """
    parser.add_argument('-nh', '--n_hidden', dest='n_hidden', required=True,
                        type=int, help='Number of hidden units')
    parser.add_argument('-std', '--standardize', dest='standardize', type=str2bool, required=True,
                        help='Whether to include standardization (True/False)')
    parser.add_argument('-bn', '--batchnorm', dest='batchnorm', type=str2bool, required=True,
                        help='Whether to add BatchNorm to the model (True/False)')
    parser.add_argument('-do', '--dropout', dest='dropout', type=float, default=0.0, required=False,
                        help='Whether to add DropOut to the model (p in float e[0,1], default = 0.0)')
    parser.add_argument('-ws', '--window_size', dest='window_size', type=int, default=6, required=False,
                        help='Window size for sub-mers selection (default = 6)')
    parser.add_argument('-lr', '--learning_rate', dest='lr', type=float, default=1e-4, required=False,
                        help='Learning rate for the optimizer')
    parser.add_argument('-wd', '--weight_decay', dest='wd', type=float, default=1e-2, required=False,
                        help='Weight decay for the optimizer')
    parser.add_argument('-bs', '--batch_size', dest='batch_size', type=int, default=128, required=False,
                        help='Batch size for mini-batch optimization')
    parser.add_argument('-ne', '--n_epochs', dest='n_epochs', type=int, default=500, required=False,
                        help='Number of epochs to train')
    parser.add_argument('tol', '--tolerance', dest='tolerance', type=float, default=1e-5, required=False,
                        help='Tolerance for loss variation to log best model')

# %%
drb = pd.read_csv('../data/NetMHCIIpan_train/drb1_0301.csv')
drb_train, drb_test = train_test_split(drb, test_size=1/5)
drb_train.to_csv('../data/NetMHCIIpan_train/drb_train.csv', index=False)
drb_test.to_csv('../data/NetMHCIIpan_train/drb_test.csv', index=False)

# %%
from src.datasets import *
from src.models import *
drb_loader, drb_dataset = get_NNAlign_dataloader(drb, 20, 8, 'BL50LO', 'Sequence', 'target', -15, False, return_dataset=True)
# Out:
# Pruning sequences longer than length=20.
# Nseqs Before:	23250
# Nseqs After:	20751

# %%
drb_dataset.original_x
# Out:
# tensor([[[  5.,  -2.,  -1.,  ...,  -3.,  -2.,   0.],
#          [  5.,  -2.,  -1.,  ...,  -3.,  -2.,   0.],
#          [  1.,  -1.,   1.,  ...,  -4.,  -2.,  -2.],
#          ...,
#          [  0.,  -1.,   0.,  ...,  -3.,  -2.,   0.],
#          [-15., -15., -15.,  ..., -15., -15., -15.],
#          [-15., -15., -15.,  ..., -15., -15., -15.]],
#
#         [[  5.,  -2.,  -1.,  ...,  -3.,  -2.,   0.],
#          [ -2.,  -2.,   2.,  ...,  -5.,  -3.,  -4.],
#          [ -1.,   3.,   0.,  ...,  -3.,  -2.,  -3.],
#          ...,
#          [  1.,  -1.,   1.,  ...,  -4.,  -2.,  -2.],
#          [-15., -15., -15.,  ..., -15., -15., -15.],
#          [-15., -15., -15.,  ..., -15., -15., -15.]],
#
#         [[  5.,  -2.,  -1.,  ...,  -3.,  -2.,   0.],
#          [ -2.,  -2.,   2.,  ...,  -5.,  -3.,  -4.],
#          [ -1.,   3.,   0.,  ...,  -3.,  -2.,  -3.],
#          ...,
#          [  1.,  -1.,   1.,  ...,  -4.,  -2.,  -2.],
#          [ -1.,   3.,   0.,  ...,  -3.,  -2.,  -3.],
#          [  0.,  -1.,   0.,  ...,  -3.,  -2.,   0.]],
#
#         ...,
#
#         [[ -1.,  -1.,   7.,  ...,  -4.,  -2.,  -3.],
#          [  0.,  -3.,   0.,  ...,  -3.,  -3.,  -4.],
#          [  0.,  -3.,   0.,  ...,  -3.,  -3.,  -4.],
#          ...,
#          [ -2.,  -2.,   2.,  ...,  -5.,  -3.,  -4.],
#          [  0.,  -3.,   0.,  ...,  -3.,  -3.,  -4.],
#          [ -1.,   1.,   0.,  ...,  -1.,  -1.,  -3.]],
#
#         [[ -1.,  -3.,  -2.,  ...,  -4.,  -3.,  -3.],
#          [  0.,  -3.,   0.,  ...,  -3.,  -3.,  -4.],
#          [ -1.,   3.,   0.,  ...,  -3.,  -2.,  -3.],
#          ...,
#          [ -2.,  -1.,  -2.,  ...,   2.,   8.,  -1.],
#          [ -2.,  -1.,  -2.,  ...,   2.,   8.,  -1.],
#          [ -1.,  -1.,   7.,  ...,  -4.,  -2.,  -3.]],
#
#         [[ -2.,  -3.,  -4.,  ...,  -2.,  -1.,   1.],
#          [ -1.,  -3.,  -2.,  ...,  -4.,  -3.,  -3.],
#          [ -1.,  -4.,  -2.,  ...,  -5.,  -3.,  -1.],
#          ...,
#          [ -2.,   7.,  -1.,  ...,  -3.,  -1.,  -3.],
#          [ -1.,   0.,   0.,  ...,  -3.,  -2.,  -3.],
#          [  1.,  -1.,   1.,  ...,  -4.,  -2.,  -2.]]])

# %%
drb_loader.dataset.

# %%
drb_dataset

# %%
def run(df_train, df_test, model_constructor, encoding, n_hidden, window_size, p_drop, batchnorm, activation, 
        batch_size=64, n_epochs = 500, lr = 1e-4, wd = 1e-2, id_='', outdir='../output/', seed=13, singlepass=False,):
    start = dt.now()
    torch.manual_seed(seed)
    model = model_constructor(n_hidden=n_hidden, window_size=window_size, activation = activation, dropout=p_drop, singlepass=singlepass)
    train_loader, train_dataset = get_NNAlign_dataloader(df_train, 12, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=True)
    test_loader = get_NNAlign_dataloader(df_test, 12, window_size, encoding, seq_col='Peptide', target_col='agg_label', pad_scale=None, batch_size=batch_size, return_dataset=False)
                         
    if hasattr(model, 'standardizer'):
        model.fit_standardizer(train_dataset[:][0])
        
    criterion = nn.BCEWithLogitsLoss(reduction='mean')
    optimizer = optim.Adam(model.parameters(), lr = lr, weight_decay = wd)
    
    train_losses = []
    test_losses = []

    train_aucs = []
    test_aucs = []


    print('Before training')
    loss, metrics = eval_model_step(model, criterion, train_loader)
    train_losses.append(loss)
    train_aucs.append(metrics['auc'])
    loss, metrics = eval_model_step(model, criterion, test_loader)
    test_losses.append(loss)
    test_aucs.append(metrics['auc'])
    
    
    for e in tqdm(range(1,n_epochs+1), desc='Training epochs', leave=False):
        if e==1:print('Start training')
        loss, metrics = train_model_step(model, criterion, optimizer, train_loader)
        train_losses.append(loss)
        train_aucs.append(metrics['auc'])
        loss, metrics = eval_model_step(model, criterion, test_loader)
        test_losses.append(loss)
        test_aucs.append(metrics['auc'])
    end = dt.now()
    elapsed = (end-start).seconds
    
    f,a = plt.subplots(2,1, figsize=(12,10))
    a = a.ravel()
    a[0].plot(train_losses, label='train_losses')
    a[0].plot(test_losses, label='test_losses')
    a[0].legend()
    a[0].set_title('loss')
    a[1].plot(train_aucs, label='train_aucs')
    a[1].plot(test_aucs, label='test_aucs')
    a[1].legend()
    a[1].set_title('AUC')
    a[1].set_xlabel('epochs')
    f.suptitle(f'IDENTIFIER: {id_}\nStd:{hasattr(model, "standardizer")}, nh:{n_hidden}, drop:{p_drop}, BN:{batchnorm},\nBS:{batch_size}, act:{activation.__class__.__name__}, enc:{encoding}, lr:{lr:.2e}, wd:{wd:.2e}')
    filename=f'ID_{id_}_SEED_{seed}_std_{hasattr(model, "standardizer")}_nh_{n_hidden}_drop_{p_drop}_bn_{batchnorm}_bs_{batch_size}_act_{activation.__class__.__name__}_enc_{encoding}_lr1em4_wd_1em2'
    f.tight_layout()
    f.savefig(f'../output/{outdir}{filename}.png', bbox_inches='tight', dpi=200)
    
    dd={'best_train_loss': np.min(train_losses),
     'best_train_loss_idx': np.argmin(train_losses),
     'best_test_loss': np.min(test_losses),
     'best_test_loss_idx': np.argmin(test_losses),
     'best_train_auc': np.max(train_aucs),
     'best_train_auc_idx': np.argmax(train_aucs),
     'best_test_auc': np.max(test_aucs),
     'best_test_auc_idx': np.argmax(test_aucs),
     'std': hasattr(model, 'standardizer'),
     'n_hidden':n_hidden,
     'drop':p_drop,
     'batchnorm':batchnorm,
     'batchsize':batch_size,
     'act':activation.__class__.__name__,
     'encoding':encoding,
       'identifier':id_,
       'seed':seed,
       'elapsed_seconds':elapsed}
    return pd.DataFrame(dd, index=[0])

# %% [markdown]
# # Reading DRB1_0301 results

# %%
# Done with motif length 9
from sklearn.metrics import roc_auc_score, roc_curve
def get_motif(row):
    return row['Sequence'][int(row['core_start_index']):int(row['core_start_index'])+9]

PATH = '../output/230524_MHCII_DRB1_0301_kcvs/'
dirs = list(filter(lambda x: 'run_MHC' in x, os.listdir(PATH)))
preds = []
for dnms in dirs:
    preds.append(pd.read_csv(f"{PATH}{dnms}/{list(filter(lambda x: 'valid_pred' in x, os.listdir(f'{PATH}{dnms}')))[0]}"))
preds = pd.concat(preds)
preds['motif'] = preds.apply(get_motif, axis=1)

# %%
f,a = plt.subplots(1,1, figsize=(8,8))
auc = roc_auc_score(preds['label'].astype(int), preds['pred'])
fpr, tpr, _ = roc_curve(preds['label'].astype(int), preds['pred'])
sns.lineplot(x=fpr, y=tpr, label=f'All motif lengths: AUC={auc:.4f}', estimator = None, ls='--', lw=1, ax=a)

auc = roc_auc_score(preds.query('motif_len!=9')['label'].astype(int), preds.query('motif_len!=9')['pred'])
fpr, tpr, _ = roc_curve(preds.query('motif_len!=9')['label'].astype(int), preds.query('motif_len!=9')['pred'])
sns.lineplot(x=fpr, y=tpr, label=f'Non 9mers motifs: AUC={auc:.4f}', estimator=None, ls='--', lw=1, ax=a)


auc = roc_auc_score(preds.query('motif_len==9')['label'].astype(int), preds.query('motif_len==9')['pred'])
fpr, tpr, _ = roc_curve(preds.query('motif_len==9')['label'].astype(int), preds.query('motif_len==9')['pred'])
sns.lineplot(x=fpr, y=tpr, label=f'only 9mers motifs: AUC={auc:.4f}', estimator=None,ls='--', lw=1,  ax=a)
a.set_title('My model does something wrong sometimes\nand selects the wrong motif lengths (because of padding)')
f.savefig(f'{PATH}roc_curve_valid.png', dpi=300, bbox_inches='tight')

# %%
preds['motif_len'] = preds['motif'].apply(len)
preds.groupby(['motif_len', 'target']).agg(count=('Sequence','count'))
# Out:
#                   count
# motif_len target
# 1         0         159
# 2         0         305
#           1           4
# 3         0         483
#           1           3
# 4         0         513
#           1           5
# 5         0         457
#           1           2
# 6         0         339
#           1           3
# 7         0         334
#           1           1
# 8         0         372
#           1           3
# 9         0       17965
#           1        2302

# %%
preds.query('motif_len==9 and label==1')['motif'].to_csv(f'{PATH}pred_motif_binders.txt', index=False,header=None)
preds.query('motif_len==9 and label==0')['motif'].to_csv(f'{PATH}pred_motif_non_binders.txt', index=False,header=None)
preds.query('motif_len==9')['motif'].to_csv(f'{PATH}pred_motif_both.txt', index=False,header=None)
